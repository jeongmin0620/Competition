# %%
import pandas as pd
import warnings
import os
import matplotlib.pyplot as plt
import glob
import os.path

data = pd.read_csv('C:\\Users\\hwang\\data\\sample.csv', encoding = 'euc-kr')

# %% [markdown]
# #### 데이터 기본정보

# %%
data.head()
data.info()
data.columns
data.isnull().sum()
data.describe()
# Out:
#        CoilNO        제품종류  제품Size           압연시작일시           압연완료일시  \
# 0  Q540024003  Product_17     7.0  2016-01-01 5:56  2016-01-01 6:00
# 1  Q540027003  Product_17     7.0  2016-01-01 5:57  2016-01-01 6:02
# 2  Q540030003  Product_17     7.0  2016-01-01 5:59  2016-01-01 6:03
# 3  Q540033003  Product_17     7.0  2016-01-01 6:00  2016-01-01 6:04
# 4  Q540036003  Product_17     7.0  2016-01-01 6:01  2016-01-01 6:05
#
#    Descaler.No1_Pressure  Descaler.No2_Pressure  조압연입측소재온도  조압연입측소재온도.1  \
# 0                    243                    142       1065            0
# 1                    253                    143       1062            0
# 2                    225                    141       1061            0
# 3                    235                    143       1064            0
# 4                    251                    142       1061            0
#
#    중간사상압연_No2_출측소재온도  ...  Middle.Cooling Zone#4(4WB)유량  \
# 0               1030  ...                         410.9
# ...

# %%
data.columns
# Out:
# Index(['CoilNO', '제품종류', '제품Size', '압연시작일시', '압연완료일시', 'Descaler.No1_Pressure',
#        'Descaler.No2_Pressure', '조압연입측소재온도', '조압연입측소재온도.1',
#        '중간사상압연_No2_출측소재온도', '선재사상압연입측소재온도', '선재사상압연출측소재온도', '최종압연 입측소재온도',
#        '선재 Wire Rod 인출장치 출측소재온도', '조압연입측속도', '조압연출측속도', '중간압연1출측속도',
#        '중간압연2출측속도', '중간사상압연_No2_출측속도', '선재사상압연출측속도', '최종압연 출측속도',
#        '선재 Wire Rod 인출장치 진입속도', 'First.Cooling Zone#1(1WB)유량',
#        'First.Cooling Zone#1(1WB)압력', 'First.Cooling Zone#2(2WB)유량',
#        'First.Cooling Zone#2(2WB)압력', 'Middle.Cooling Zone#1(1WB)유량',
#        'Middle.Cooling Zone#1(1WB)압력', 'Middle.Cooling Zone#2(2WB)유량',
#        'Middle.Cooling Zone#2(2WB)압력', 'Middle.Cooling Zone#3(3WB)유량',
#        'Middle.Cooling Zone#3(3WB)압력', 'Middle.Cooling Zone#4(4WB)유량',
#        'Middle.Cooling Zone#4(4WB)압력', 'Last.Cooling Zone#1(1WB)유량',
#        'Last.Cooling Zone#1(1WB)압력', 'Last.Cooling Zone#2(2WB)유량',
# ...

# %% [markdown]
# #### 데이터 판다스 프로파일링

# %%
import pandas as pd
import pandas_profiling
data = pd.read_csv('C:\\Users\\hwang\\data\\sample.csv', encoding = 'euc-kr')

# %%
profile = data.profile_report(interactions={'continuous': False}) # 산점도만 제외
#profile.to_file('C:\\Users\\hwang\\Desktop\\pr_report_all.html') #파일로 저장
profile.to_file(output_file="C:\\Users\\hwang\\Desktop\\pr_report.html")
# Out:
# Summarize dataset:   0%|          | 0/55 [00:00<?, ?it/s]
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\textpath.py:74: RuntimeWarning: Glyph 51228 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\textpath.py:74: RuntimeWarning: Glyph 54408 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\textpath.py:74: RuntimeWarning: Glyph 51333 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\textpath.py:74: RuntimeWarning: Glyph 47448 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\textpath.py:74: RuntimeWarning: Glyph 50517 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# ...

# %%
#요약데이터
from pandas_profiling import ProfileReport

profile = ProfileReport(data, minimal=True)
profile.to_file(output_file="C:\\Users\\hwang\\Desktop\\pr_report.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# #### 데이터 IQR (이상치(outlier) 탐지)

# %%
import pandas as pd
num = data

Q0  = num.quantile(.0) #최소
Q1 = num.quantile(.01) #1%분위
Q25 = num.quantile(.25) #25%분위
Q50 = num.quantile(.5) #50%분위(중앙값)
Q75 = num.quantile(.75) #75%분위
Q99 = num.quantile(.99) #99%분위
Q100 = num.quantile(1) #100%분위
IQR = Q3 - Q1

print("Q0 =",Q0)
print("Q1 =",Q1)
print("Q25 =",Q25)
print("Q50 =",Q50)
print("Q75 =",Q75)
print("Q99 =",Q99)
print("Q100 =",Q100)
print("IQR(Q3-Q1) =", IQR)
# Out:
# Q0 = 제품Size                            5.5000
# Descaler.No1_Pressure             0.0000
# Descaler.No2_Pressure             0.0000
# 조압연입측소재온도                         0.0000
# 조압연입측소재온도.1                       0.0000
# 중간사상압연_No2_출측소재온도                 0.0000
# 선재사상압연입측소재온도                      0.0000
# 선재사상압연출측소재온도                      0.0000
# 최종압연 입측소재온도                       0.0000
# 선재 Wire Rod 인출장치 출측소재온도           0.0000
# 조압연입측속도                           0.0000
# 조압연출측속도                           0.0000
# 중간압연1출측속도                         0.0000
# 중간압연2출측속도                         0.0000
# 중간사상압연_No2_출측속도                   0.0000
# 선재사상압연출측속도                        0.0000
# 최종압연 출측속도                         0.0000
# 선재 Wire Rod 인출장치 진입속도             0.0000
# First.Cooling Zone#1(1WB)유량       0.0000
# First.Cooling Zone#1(1WB)압력       0.0000
# First.Cooling Zone#2(2WB)유량       0.0000
# First.Cooling Zone#2(2WB)압력       0.0000
# Middle.Cooling Zone#1(1WB)유량      0.0000
# ...

# %% [markdown]
# #### 데이터 IQR (이상치(outlier) 탐지) 시각화

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [10, 6]
# %matplotlib inline
data = pd.read_csv('C:\\Users\\hwang\\data\\sample.csv', encoding = 'euc-kr')

# %%
data1 = data[['Descaler.No1_Pressure', 'Descaler.No2_Pressure']]
data2 = data[['조압연입측소재온도', 
'조압연입측소재온도.1', 
'중간사상압연_No2_출측소재온도', 
'선재사상압연입측소재온도', 
'선재사상압연출측소재온도', 
'최종압연 입측소재온도', 
'선재 Wire Rod 인출장치 출측소재온도', 
'조압연입측속도', 
'조압연출측속도', 
'중간압연1출측속도', 
'중간압연2출측속도', 
'중간사상압연_No2_출측속도', 
'선재사상압연출측속도', 
'최종압연 출측속도', 
'선재 Wire Rod 인출장치 진입속도']]
data3 = data[['First.Cooling Zone#1(1WB)유량', 
'First.Cooling Zone#1(1WB)압력', 
'First.Cooling Zone#2(2WB)유량', 
'First.Cooling Zone#2(2WB)압력', 
'Middle.Cooling Zone#1(1WB)유량', 
'Middle.Cooling Zone#1(1WB)압력', 
'Middle.Cooling Zone#2(2WB)유량', 
'Middle.Cooling Zone#2(2WB)압력', 
'Middle.Cooling Zone#3(3WB)유량', 
'Middle.Cooling Zone#3(3WB)압력', 
'Middle.Cooling Zone#4(4WB)유량', 
'Middle.Cooling Zone#4(4WB)압력', 
'Last.Cooling Zone#1(1WB)유량', 
'Last.Cooling Zone#1(1WB)압력', 
'Last.Cooling Zone#2(2WB)유량', 
'Last.Cooling Zone#2(2WB)압력']]
data4 = data[['Rolling Time', 
'Idle Time', 
'압연 Pitch', 
'선재사상압연모터전류']]

# %%
plt.boxplot(data1)
#plt.xticks([1, 2], ['Descaler.No1_Pressure', 'Descaler.No2_Pressure'])
plt.show()

# %%
plt.boxplot(data2)
#plt.xticks([1, 2], ['Descaler.No1_Pressure', 'Descaler.No2_Pressure'])
plt.show()

# %%
plt.boxplot(data3)
#plt.xticks([1, 2], ['Descaler.No1_Pressure', 'Descaler.No2_Pressure'])
plt.show()

# %%
plt.boxplot(data4)
#plt.xticks([1, 2], ['Descaler.No1_Pressure', 'Descaler.No2_Pressure'])
plt.show()

# %%
import pandas as pd
data = pd.read_csv('C:\\Users\\hwang\\data\\sample.csv', encoding = 'euc-kr')
num = data


Q25 = num.quantile(.25) #25%분위
Q50 = num.quantile(.5) #50%분위(중앙값)
Q75 = num.quantile(.75) #75%분위
IQR = Q75 - Q25

print("Q25 =",Q25)
print("Q50 =",Q50)
print("Q75 =",Q75)
print("Minimun =", Q25-(1.5*IQR))
print("Maximun =", Q75+(1.5*IQR))

data = data[(data['fare'] < upper) & (data['fare'] > lower)]
len(data)
# Out:
# Q25 = 제품Size                             6.500000
# Descaler.No1_Pressure            243.000000
# Descaler.No2_Pressure              0.000000
# 조압연입측소재온도                        997.000000
# 조압연입측소재온도.1                        0.000000
# 중간사상압연_No2_출측소재온도                981.000000
# 선재사상압연입측소재온도                     948.000000
# 선재사상압연출측소재온도                     979.000000
# 최종압연 입측소재온도                      929.000000
# 선재 Wire Rod 인출장치 출측소재온도          853.000000
# 조압연입측속도                         1370.100000
# 조압연출측속도                         1245.500000
# 중간압연1출측속도                       1026.100000
# 중간압연2출측속도                        793.300000
# 중간사상압연_No2_출측속도                  270.000000
# 선재사상압연출측속도                       875.500000
# 최종압연 출측속도                       1046.800000
# 선재 Wire Rod 인출장치 진입속도            895.600000
# First.Cooling Zone#1(1WB)유량      112.700000
# First.Cooling Zone#1(1WB)압력        0.000000
# First.Cooling Zone#2(2WB)유량      110.900000
# ...

# %%
import pandas as pd
data = pd.read_csv('C:\\Users\\hwang\\data\\sample.csv', encoding = 'euc-kr')

def outlier_iqr(data, column): 

    # lower, upper 글로벌 변수 선언하기     
    global lower, upper    
    
    # 4분위수 기준 지정하기     
    q25, q75 = np.quantile(data[column], 0.25), np.quantile(data[column], 0.75)          
    
    # IQR 계산하기     
    iqr = q75 - q25    
    
    # outlier cutoff 계산하기     
    cut_off = iqr * 1.5          
    
    # lower와 upper bound 값 구하기     
    lower, upper = q25 - cut_off, q75 + cut_off     
    
    print(column)
    print('IQR은',iqr, '이다.')     
    print('lower bound 값은', lower, '이다.')     
    print('upper bound 값은', upper, '이다.')    
    
    # 1사 분위와 4사 분위에 속해있는 데이터 각각 저장하기     
    data1 = data[data[column] > upper]     
    data2 = data[data[column] < lower]    
    
    # 이상치 총 개수 구하기
    return print('총 이상치 개수는', data1.shape[0] + data2.shape[0], '이다.')

# %%
a = ['조압연입측소재온도', 
'조압연입측소재온도.1', 
'중간사상압연_No2_출측소재온도', 
'선재사상압연입측소재온도', 
'선재사상압연출측소재온도', 
'최종압연 입측소재온도', 
'선재 Wire Rod 인출장치 출측소재온도', 
'조압연입측속도', 
'조압연출측속도', 
'중간압연1출측속도', 
'중간압연2출측속도', 
'중간사상압연_No2_출측속도', 
'선재사상압연출측속도', 
'최종압연 출측속도', 
'선재 Wire Rod 인출장치 진입속도',
'First.Cooling Zone#1(1WB)유량', 
'First.Cooling Zone#1(1WB)압력', 
'First.Cooling Zone#2(2WB)유량', 
'First.Cooling Zone#2(2WB)압력', 
'Middle.Cooling Zone#1(1WB)유량', 
'Middle.Cooling Zone#1(1WB)압력', 
'Middle.Cooling Zone#2(2WB)유량', 
'Middle.Cooling Zone#2(2WB)압력', 
'Middle.Cooling Zone#3(3WB)유량', 
'Middle.Cooling Zone#3(3WB)압력', 
'Middle.Cooling Zone#4(4WB)유량', 
'Middle.Cooling Zone#4(4WB)압력', 
'Last.Cooling Zone#1(1WB)유량', 
'Last.Cooling Zone#1(1WB)압력', 
'Last.Cooling Zone#2(2WB)유량', 
'Last.Cooling Zone#2(2WB)압력',
'Rolling Time', 
'Idle Time', 
'압연 Pitch', 
'선재사상압연모터전류']

# %%
for i in a:
    outlier_iqr(data,i)
    print('\n')
# Out:
# 조압연입측소재온도
# IQR은 45.0 이다.
# lower bound 값은 929.5 이다.
# upper bound 값은 1109.5 이다.
# 총 이상치 개수는 8587 이다.
#
#
# 조압연입측소재온도.1
# IQR은 1024.0 이다.
# lower bound 값은 -1536.0 이다.
# upper bound 값은 2560.0 이다.
# 총 이상치 개수는 0 이다.
#
#
# 중간사상압연_No2_출측소재온도
# IQR은 63.0 이다.
# lower bound 값은 886.5 이다.
# upper bound 값은 1138.5 이다.
# 총 이상치 개수는 709 이다.
#
#
# 선재사상압연입측소재온도
# IQR은 20.0 이다.
# lower bound 값은 918.0 이다.
# upper bound 값은 998.0 이다.
# 총 이상치 개수는 13978 이다.
#
#
# 선재사상압연출측소재온도
# IQR은 61.0 이다.
# lower bound 값은 887.5 이다.
# upper bound 값은 1131.5 이다.
# 총 이상치 개수는 4595 이다.
#
#
# 최종압연 입측소재온도
# IQR은 17.0 이다.
# lower bound 값은 903.5 이다.
# upper bound 값은 971.5 이다.
# 총 이상치 개수는 4085 이다.
#
#
# 선재 Wire Rod 인출장치 출측소재온도
# IQR은 15.0 이다.
# lower bound 값은 830.5 이다.
# upper bound 값은 890.5 이다.
# 총 이상치 개수는 7881 이다.
#
#
# 조압연입측속도
# IQR은 235.4000000000001 이다.
# lower bound 값은 1016.9999999999998 이다.
# upper bound 값은 1958.6000000000001 이다.
# 총 이상치 개수는 6 이다.
#
#
# 조압연출측속도
# IQR은 40.0 이다.
# lower bound 값은 1185.5 이다.
# ...
